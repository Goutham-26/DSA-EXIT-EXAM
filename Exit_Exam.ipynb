# %% [markdown]
# <a href="https://colab.research.google.com/github/Goutham-26/DSA-EXIT-EXAM/blob/main/Exit_Exam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Task 1

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('/content/G2.csv')
data.head(10)
# Out:
#    id        name  height_dm  weight_hg  base_experience type_1  type_2  hp  \
# 0   1   bulbasaur          7         69             64.0  grass  poison  45
# 1   2     ivysaur         10        130            142.0  grass  poison  60
# 2   3    venusaur         20       1000            236.0  grass  poison  80
# 3   4  charmander          6         85             62.0   fire     NaN  39
# 4   5  charmeleon         11        190            142.0   fire     NaN  58
# 5   6   charizard         17        905            240.0   fire  flying  78
# 6   7    squirtle          5         90             63.0  water     NaN  44
# 7   8   wartortle         10        225            142.0  water     NaN  59
# 8   9   blastoise         16        855            239.0  water     NaN  79
# 9  10    caterpie          3         29             39.0    bug     NaN  45
#
#    attack  defense
# 0      49       49
# 1      62       63
# 2      82       83
# 3      52       43
# 4      64       58
# ...

# %%
numeric_cols = data.select_dtypes(include=['number']).columns
numeric_cols
# Out:
# Index(['id', 'height_dm', 'weight_hg', 'base_experience', 'hp', 'attack',
#        'defense'],
#       dtype='object')

# %%
data.shape
# Out:
# (1351, 10)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1351 entries, 0 to 1350
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1351 non-null   int64
#  1   name             1351 non-null   object
#  2   height_dm        1351 non-null   int64
#  3   weight_hg        1351 non-null   int64
#  4   base_experience  1302 non-null   float64
#  5   type_1           1351 non-null   object
#  6   type_2           765 non-null    object
#  7   hp               1351 non-null   int64
#  8   attack           1351 non-null   int64
#  9   defense          1351 non-null   int64
# dtypes: float64(1), int64(6), object(3)
# memory usage: 105.7+ KB

# %%
data.isnull().sum()
# Out:
# id                   0
# name                 0
# height_dm            0
# weight_hg            0
# base_experience     49
# type_1               0
# type_2             586
# hp                   0
# attack               0
# defense              0
# dtype: int64

# %%
import missingno as msno
msno.matrix(data)
# Out:
# <Axes: >

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.drop_duplicates(inplace=True)

# %%
data.shape
# Out:
# (1351, 10)

# %%
data.describe()
# Out:
#                  id    height_dm     weight_hg  base_experience           hp  \
# count   1351.000000  1351.000000   1351.000000      1302.000000  1351.000000
# mean    2841.692080    20.443375    991.059956       161.943932    71.673575
# std     4139.019112    53.238467   1953.115812        82.532554    26.827529
# min        1.000000     1.000000      0.000000        36.000000     1.000000
# 25%      338.500000     6.000000     94.500000        71.000000    55.000000
# 50%      676.000000    11.000000    326.000000       165.000000    70.000000
# 75%     1013.500000    17.000000    853.500000       222.500000    85.000000
# max    10326.000000  1000.000000  10000.000000       608.000000   255.000000
#
#             attack      defense
# count  1351.000000  1351.000000
# mean     82.757957    76.193930
# std      32.351906    30.712902
# min       5.000000     5.000000
# 25%      60.000000    55.000000
# 50%      80.000000    70.000000
# 75%     102.500000    95.000000
# ...

# %%
pokemon_counts = data["name"].value_counts()

# %%
most_frequent_pokemon = pokemon_counts.idxmax()
frequency = pokemon_counts.max()

print("Most frequent Pokemon:", most_frequent_pokemon)
print("Number of appearances:", frequency)
# Out:
# Most frequent Pokemon: meowstic-female-mega
# Number of appearances: 1

# %%
frequency_by_type = data.groupby("type_1")["name"].count()
frequency_by_type
# Out:
# type_1
# bug          95
# dark         63
# dragon       59
# electric    100
# fairy        35
# fighting     62
# fire         84
# flying       13
# ghost        52
# grass       122
# ground       50
# ice          44
# normal      139
# poison       52
# psychic      86
# rock         83
# steel        52
# water       160
# Name: name, dtype: int64

# %% [markdown]
# which pokemon appears most frequently in  the dataset
#
# No single Pokémon appeared most frequently. Every Pokémon name appears once in the dataset, so they are all tied.

# %% [markdown]
# which numerical feature showed the greatest variation amoung pokemon
#
# here the id given showed a greatest variation because when compared with std and others it showed a greater variation

# %% [markdown]
# what

# %% [markdown]
# task 2

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
msno.matrix(data)
# Out:
# <Axes: >

# %%
skewness = data.skew(numeric_only=True)
skewness
# Out:
# id                 1.197407
# height_dm          9.348093
# weight_hg          3.492946
# base_experience    0.483442
# hp                 1.583820
# attack             0.402718
# defense            1.003514
# dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

numerical_cols = data.select_dtypes(include=['int64', 'float64']).columns

num_cols = len(numerical_cols)
num_rows = (num_cols + 2) // 3

plt.figure(figsize=(18, 5 * num_rows))
for i, col in enumerate(numerical_cols):
    plt.subplot(num_rows, 3, i + 1)
    sns.boxplot(y=data[col])
    plt.title(f'Box plot of {col}')
    plt.ylabel('')
plt.tight_layout()
plt.show()

# %%
numeric_cols = data.select_dtypes(include=['number']).columns
data[numeric_cols] = data[numeric_cols].fillna(data[numeric_cols].median())

# %%
data.head(10)
# Out:
#    id        name  height_dm  weight_hg  base_experience type_1  type_2  hp  \
# 0   1   bulbasaur          7         69             64.0  grass  poison  45
# 1   2     ivysaur         10        130            142.0  grass  poison  60
# 2   3    venusaur         20       1000            236.0  grass  poison  80
# 3   4  charmander          6         85             62.0   fire     NaN  39
# 4   5  charmeleon         11        190            142.0   fire     NaN  58
# 5   6   charizard         17        905            240.0   fire  flying  78
# 6   7    squirtle          5         90             63.0  water     NaN  44
# 7   8   wartortle         10        225            142.0  water     NaN  59
# 8   9   blastoise         16        855            239.0  water     NaN  79
# 9  10    caterpie          3         29             39.0    bug     NaN  45
#
#    attack  defense
# 0      49       49
# 1      62       63
# 2      82       83
# 3      52       43
# 4      64       58
# ...

# %%
if data[col].dtype == 'object':
            data[col] = data[col].fillna(data[col].mode()[0])
            print(f"Mode applied to: {col}")

# %%
data.head(10)
# Out:
#    id        name  height_dm  weight_hg  base_experience type_1  type_2  hp  \
# 0   1   bulbasaur          7         69             64.0  grass  poison  45
# 1   2     ivysaur         10        130            142.0  grass  poison  60
# 2   3    venusaur         20       1000            236.0  grass  poison  80
# 3   4  charmander          6         85             62.0   fire     NaN  39
# 4   5  charmeleon         11        190            142.0   fire     NaN  58
# 5   6   charizard         17        905            240.0   fire  flying  78
# 6   7    squirtle          5         90             63.0  water     NaN  44
# 7   8   wartortle         10        225            142.0  water     NaN  59
# 8   9   blastoise         16        855            239.0  water     NaN  79
# 9  10    caterpie          3         29             39.0    bug     NaN  45
#
#    attack  defense
# 0      49       49
# 1      62       63
# 2      82       83
# 3      52       43
# 4      64       58
# ...

# %%
msno.matrix(data)
# Out:
# <Axes: >

# %%
data = data.drop(columns=["type_2"])

# %%
data.head(10)
# Out:
#    id        name  height_dm  weight_hg  base_experience type_1  hp  attack  \
# 0   1   bulbasaur          7         69             64.0  grass  45      49
# 1   2     ivysaur         10        130            142.0  grass  60      62
# 2   3    venusaur         20       1000            236.0  grass  80      82
# 3   4  charmander          6         85             62.0   fire  39      52
# 4   5  charmeleon         11        190            142.0   fire  58      64
# 5   6   charizard         17        905            240.0   fire  78      84
# 6   7    squirtle          5         90             63.0  water  44      48
# 7   8   wartortle         10        225            142.0  water  59      63
# 8   9   blastoise         16        855            239.0  water  79      83
# 9  10    caterpie          3         29             39.0    bug  45      30
#
#    defense
# 0       49
# 1       63
# 2       83
# 3       43
# 4       58
# 5       78
# 6       65
# 7       80
# 8      100
# ...

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()

for column in ["name", "type_1"]:
    data[column] = encoder.fit_transform(data[column])

# %%
data.head()
# Out:
#    id  name  height_dm  weight_hg  base_experience  type_1  hp  attack  \
# 0   1   121          7         69             64.0       9  45      49
# 1   2   555         10        130            142.0       9  60      62
# 2   3  1257         20       1000            236.0       9  80      82
# 3   4   163          6         85             62.0       6  39      52
# 4   5   164         11        190            142.0       6  58      64
#
#    defense
# 0       49
# 1       63
# 2       83
# 3       43
# 4       58

# %%
corr = data.corr(numeric_only = True)
plt.figure(figsize=(8,6))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
y = data['base_experience']
x = data.drop(columns=['base_experience'])

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
std_scalar = StandardScaler()

numeric_col = x_train.select_dtypes(include=['int64', 'float64']).columns

x_train[numeric_col] = std_scalar.fit_transform(x_train[numeric_col])
x_test[numeric_col] = std_scalar.transform(x_test[numeric_col])

x_train.head()
# Out:
#             id      name  height_dm  weight_hg    type_1        hp    attack  \
# 756  -0.514294  0.816812  -0.268698  -0.480614  0.684644 -0.860018 -1.207148
# 109  -0.669139  1.575014  -0.163941  -0.457244  0.684644 -0.245672  0.225408
# 1027  1.698531 -1.074839  -0.076644  -0.202166  0.865873 -0.787742  0.381121
# 549  -0.563835 -1.552892  -0.198860  -0.414980  1.409561 -0.064982  0.287694
# 486  -0.578913 -0.643049   0.412221   3.224737 -0.221502  2.826060  0.536834
#
#        defense
# 756  -1.158212
# 109   1.410308
# 1027  0.447113
# 549  -0.355550
# 486   1.410308

# %% [markdown]
# Why is preprocessing essential before model training
#
# beacuse in preprocesing , the null values, other values and the data set is fixed properly for gaining maximum accuracy for model training

# %% [markdown]
# how did you handle the mising values in type _ 2
#
# since there are around 586 missing values , i have dropped the entire column , because if we add data using mode ,the accuracy gained will be very low or in accurate so dropped the column

# %% [markdown]
# test 3

# %%
# Scatter plot: Attack vs Defense
plt.figure(figsize=(8, 5))
plt.scatter(data["attack"], data["defense"], alpha=0.6)

plt.title("Attack vs Defense")
plt.xlabel("Attack")
plt.ylabel("Defense")
plt.grid(True)
plt.show()

# %%
# Group HP values by primary Pokémon type
hp_by_type = [
    group["hp"].dropna()
    for _, group in df.groupby("type_1")
]

type_names = df.groupby("type_1").groups.keys()

# Create the box plot
plt.figure(figsize=(12, 6))
plt.boxplot(hp_by_type, labels=type_names)

plt.title("HP Distribution Across Pokemon Types")
plt.xlabel("Pokemon Type")
plt.ylabel("HP")
plt.xticks(rotation=45)
plt.grid(axis="y", alpha=0.4)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_2128/1178565727.py:11: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(hp_by_type, labels=type_names)

# %%
# Base experience grouped by primary type
experience_by_type = [
    group["base_experience"].dropna()
    for _, group in data.groupby("type_1")
]

type_names = data.groupby("type_1").groups.keys()

# Create the box plot
plt.figure(figsize=(12, 6))
plt.boxplot(experience_by_type, labels=type_names)

plt.title("Base Experience Distribution Across Pokemon Types")
plt.xlabel("Pokemon Type")
plt.ylabel("Base Experience")
plt.xticks(rotation=45)
plt.grid(axis="y", alpha=0.4)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_2128/549429791.py:11: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(experience_by_type, labels=type_names)

# %%
# Scatter plot
plt.figure(figsize=(8, 5))
plt.scatter(data["height_dm"], data["weight_hg"], alpha=0.6, color="green")

plt.title("Pokemon Height vs Weight")
plt.xlabel("Height (decimeters)")
plt.ylabel("Weight (hectograms)")
plt.grid(True, alpha=0.4)
plt.tight_layout()
plt.show()

# %% [markdown]
# task 4

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)

y_pred = model.predict(x_test)

# %%
y_pred
# Out:
# array([119.25879544,  91.53850459, 149.76122067, 220.7002955 ,
#         97.2558142 , 225.0688402 , 212.19582002, 120.2704745 ,
#         94.27305289, 120.04131092, 184.52883509, 112.92766596,
#         68.97579563, 216.38219498, 227.11330395, 129.6219492 ,
#        147.73430781,  64.40630723, 293.08884277, 186.45720298,
#        153.76256664,  25.67115194, 184.58593047, 151.41759919,
#         73.22889585, 266.48677695,  84.52924982, 274.99743436,
#        218.81228416, 200.02831031, 148.68958847, 101.55741453,
#        216.69970247, 144.57460327, 154.6640667 , 222.75218765,
#         64.36321645, 183.69346885, 217.40775129, 195.66281299,
#        144.64552568,  60.70280292,  61.73920948, 207.14145016,
#        211.64363077, 120.48017272, 226.83895311, 147.05694418,
#        108.44292335, 198.09628956, 153.25108557, 188.77248574,
#        208.42188009, 183.8539727 , 228.51576867, 120.06111309,
#        246.86545849, 165.40713228, 114.32442628, 215.56328889,
# ...

# %%
y_test
# Out:
# 370      60.0
# 265      72.0
# 312     151.0
# 634     270.0
# 579      61.0
#         ...
# 1281    165.0
# 467     245.0
# 723     239.0
# 54      175.0
# 820      49.0
# Name: base_experience, Length: 271, dtype: float64

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
mse=mean_squared_error(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)
r2=r2_score(y_test,y_pred)
print("MSE:",mse)
print("MAE:",mae)
print("R2:",r2)
# Out:
# MSE: 2103.517319411416
# MAE: 36.26012477705482
# R2: 0.643521080312147

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

poly = PolynomialFeatures(degree=2)

x_train_poly = poly.fit_transform(x_train)
x_test_poly  = poly.transform(x_test)

lr_model = LinearRegression()
lr_model.fit(x_train_poly, y_train)

y_pred = lr_model.predict(x_test_poly)

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
mse=mean_squared_error(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)
r2=r2_score(y_test,y_pred)
print("MSE:",mse)
print("MAE:",mae)
print("R2:",r2)
# Out:
# MSE: 2049.6910106959813
# MAE: 35.367854483565026
# R2: 0.6526429183900155

# %%
from sklearn.linear_model import Ridge,Lasso

ridge=Ridge(alpha=1.0)
ridge.fit(x_train,y_train)
print("Ridge R2",r2_score(y_test,ridge.predict(x_test)))
# Out:
# Ridge R2 0.6435588404026051

# %%
lasso=Lasso(alpha=1.0)
lasso.fit(x_train,y_train)
print("Lasso R2",r2_score(y_test,lasso.predict(x_test)))
# Out:
# Lasso R2 0.6455500695044737

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

predictions = model.predict(x_test)

weight_limit = y_train.median()

actual_classes = np.where(y_test >= weight_limit, "Heavy", "Light")
predicted_classes = np.where(predictions >= weight_limit, "Heavy", "Light")

# Create confusion matrix
cm = confusion_matrix(
    actual_classes,
    predicted_classes,
    labels=["Light", "Heavy"]
)

# Display confusion matrix
display = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=["Light", "Heavy"]
)

display.plot(cmap="Blues")
plt.title("Confusion Matrix - Polynomial Regression")
plt.show()

# %% [markdown]
# which model achieved the best performance and why
#
# polynimial regression showed the best performance because , it showed higher r2 score

# %% [markdown]
# Task 5

# %%
import pickle
from google.colab import files

# Bundle all encoders, scaler, and models into a single dictionary
ml_bundle = {
    "label_encoder": encoder,
    "standard_scaler": std_scalar,
    "linear_regression_model": model,
    "polynomial_regression_model": lr_model,
    "ridge_regression_model": ridge,
    "lasso_regression_model": lasso,
}

# 1. Save the complete bundle into a single pickle file
file_name = "ml_preprocessing_and_models_bundle.pkl"

with open(file_name, "wb") as f:
    pickle.dump(ml_bundle, f)

print("ML preprocessing and models bundle saved successfully!")

# 2. Trigger automatic download in Google Colab
files.download(file_name)
# Out:
# ML preprocessing and models bundle saved successfully!

# %% [markdown]
# how could this application  assist game developers or players
#
# new game developers may not be able to understand all the pokemons , so by using this application ,he can identify which category the specific pokemon is

# %% [markdown]
# what limitations should the users consider when intepreting the prediction
#
# random data entering or random guessing of inputs  may lead to wrong information passing
